# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from fim import apriori
from collections import Counter
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, classification_report
from sklearn.metrics import plot_confusion_matrix
import imblearn
import seaborn as sns

# %%
# Funzione che viene chiamata sul:
# - y_true: target reale
# - y_pred: target predetto dalle regole
# stampa: matrice di confusione, accuracy, precision, recall, specificity, F1
def result_pred(y_true, y_pred):
    # Calcolo dell'accuracy
    print("***** Calcolo dell'accuracy *****")
    accuracy = accuracy_score(y_true, y_pred)    
    print('Frazione di campioni correttamente correlati: %0.4f' % accuracy)
    accuracy = accuracy_score(y_true, y_pred, False)
    print("Numero di campioni correttamente correlati: ", accuracy)    
    print("____________________________________________")

# %%
path = "../DataSet/"
df = pd.read_csv(path + 'Dataset_Final.csv')
old_df = pd.read_csv(path + "Dataset.csv")
original_df = pd.read_csv(path + 'Dataset_Final.csv')

# %% [markdown]
# ## Preprocessing dei dati

# %% [markdown]
# Dati in cui avevano Missing Values:
#     - Age,
#     - TrainingTimesLastYear,
#     - YearsAtCompany
#     - PerformanceRating,
#     - Gender
#     - BusinessTravel

# %% [markdown]
# ## ---- Preprocessing dei dati
# Applicazione dei Binning alle variabili continue

# %% [markdown]
# Dividere in 5 range MonthlyIncome: Very Low; Low; Medium; High; Very High

# %%
def toRange_MonthlyIncome(df):
    ll = df['MonthlyIncome'].values
    monthly_range = []
    for i in ll:
        if i < 5000:
            monthly_range.append("Very Low")
        elif i < 9000:
            monthly_range.append("Low")
        elif i < 13000:
            monthly_range.append("Medium")
        elif i < 17000:
            monthly_range.append("High")
        else:
            monthly_range.append("Very High")
    return monthly_range

# %%
df["MonthlyIncome_Range"] = toRange_MonthlyIncome(df)

# %% [markdown]
# Divido in 4 bin le variabili YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager

# %%
def toRange_Years(df, years_toBin):
    dt = {}
    for i in years_toBin:
        ll = df[i].values
        dt[i+"_Range"]=[]
        for x in ll:
            if x <= 4:
                dt[i+"_Range"].append("<=4")
            elif x <= 8:
                dt[i+"_Range"].append(">4 <=8")
            elif x <= 12:
                dt[i+"_Range"].append(">8 <=12")
            else:
                dt[i+"_Range"].append(">12")
    return dt
        #df[i+"_Range"] = _range

# %%
years_toBin = ["YearsInCurrentRole", "YearsSinceLastPromotion", "YearsWithCurrManager"]
ll = toRange_Years(df, years_toBin)
for i in years_toBin:
    df[i+"_Range"] = ll[i+"_Range"]

# %% [markdown]
# Divido in bin le features:
# - DistanceFromHome
# - Age
# - PercentSalaryHike
# - TotalWorkingYears
# - TotalSatisfaction

# %%
df['DistanceFromHome_Range'] = pd.qcut(df['DistanceFromHome'], q=4, labels=['<=2', '>2 <=7', '>7 <=14', '>14'])
df['Age_Range'] = pd.qcut(df['Age'], q=4, labels=['<=31', '>31 <=37', '>37 <=42', '>42 <=60'])
df['PercentSalaryHike_Range'] = pd.qcut(df['PercentSalaryHike'], q=4, labels=['<=12', '>12 <=14', '>14 <=18', '>18'])
df['TotalWorkingYears_Range'] = pd.qcut(df['TotalWorkingYears'], q=4, labels=['<=6', '>6 <=10', '>10 <=15', '>15'])
df['TotalSatisfaction_Range'] = pd.qcut(df['TotalSatisfaction'], q=3, labels=['Low', 'Medium', 'High'])

# %% [markdown]
# Trasformazione delle stringhe binarie in parole diverse tra loro (per evitare confusioni)

# %%
df['Attrition'] = df['Attrition'].map(
    {"No": 'Not_Attrition', "Yes": 'Attrition'}).astype(str)
df['OverTime'] = df['OverTime'].map(
    {"No": 'Not_OverTime', "Yes": 'OverTime'}).astype(str)
df['NotValid'] = df['NotValid'].map(
    {False: 'Not_NotValid', True: 'NotValid'}).astype(str)

# %% [markdown]
# Drop delle colonne non utilizzate

# %%
df = df.drop(columns=["Age", "MonthlyIncome", "DistanceFromHome", "PercentSalaryHike", 
                      "TotalWorkingYears", "TotalSatisfaction",
                     "YearsInCurrentRole", "YearsSinceLastPromotion","YearsWithCurrManager"])

# %%
df = df.drop(columns = ["DailyRate", "EnvironmentSatisfaction", "HourlyRate",
                           "JobSatisfaction", "MonthlyRate", "WorkLifeBalance", 
                            "ProbablyLeave", "NotValid"])

# %% [markdown]
# Trasformazione degli attributi numerici in "valoreattributo_Nome"

# %%
df.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'Education',
#        'EducationField', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'MonthlyIncome_Range', 'YearsInCurrentRole_Range',
#        'YearsSinceLastPromotion_Range', 'YearsWithCurrManager_Range',
#        'DistanceFromHome_Range', 'Age_Range', 'PercentSalaryHike_Range',
#        'TotalWorkingYears_Range', 'TotalSatisfaction_Range'],
#       dtype='object')

# %%
missing_attr = ["Gender", "BusinessTravel", "PerformanceRating"]

# %% [markdown]
# Rimpiazzare i missing values di BusinessTravel, PerformanceRating, TrainingTimesLastYear con: Missing_< Nome_attributo >

# %%
missing_dict = {}
for i in missing_attr:
    missing_dict[i] = old_df[i].fillna("Missing")

# %%
for i in missing_attr:
    print(missing_dict[i].unique())
# Out:
# ['Male' 'Missing' 'Female']
# ['Travel_Rarely' 'Travel_Frequently' 'Missing' 'Non-Travel']
# [3.0 'Missing' 4.0]

# %%
df1 = df.copy()
df2 = df.copy()

# %% [markdown]
# Sostituisco le features che avevano originariamente missing values con le nuove colonne

# %%
for i in missing_attr:
    df1[i] = missing_dict[i]

# %%
for i in df1.columns:
    df1[i] = df1[i].astype(str) + '/'+str(i)

# %%
for i in missing_attr:
    original_df[i] = original_df[i].astype(str) + '/'+str(i)

# %% [markdown]
# Per calcolare l'accuracy delle predizioni in modo sintetico aggiungiamo ad ogni valore un "/NomeAttributo"

# %%
for i in missing_attr:
    print(df1[i].unique())
# Out:
# ['Male/Gender' 'Missing/Gender' 'Female/Gender']
# ['Travel_Rarely/BusinessTravel' 'Travel_Frequently/BusinessTravel'
#  'Missing/BusinessTravel' 'Non-Travel/BusinessTravel']
# ['3.0/PerformanceRating' 'Missing/PerformanceRating'
#  '4.0/PerformanceRating']

# %%
df1.columns
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'Education',
#        'EducationField', 'Gender', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'MaritalStatus', 'NumCompaniesWorked', 'OverTime', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'MonthlyIncome_Range', 'YearsInCurrentRole_Range',
#        'YearsSinceLastPromotion_Range', 'YearsWithCurrManager_Range',
#        'DistanceFromHome_Range', 'Age_Range', 'PercentSalaryHike_Range',
#        'TotalWorkingYears_Range', 'TotalSatisfaction_Range'],
#       dtype='object')

# %% [markdown]
# Trasformazione del dataset in un insieme di transazioni

# %%
df_new = df1.drop(columns = ["YearsSinceLastPromotion_Range", 
                            "YearsWithCurrManager_Range", "YearsInCurrentRole_Range"
                           , "OverTime", "RelationshipSatisfaction", "Age_Range"])

# %%
def extractRules(baskets, minz, support, confidence, valcheck):
    rules = apriori(baskets, supp=support, zmin=minz, target='r', conf=confidence, report='aSCl', mode='o')
    df_rules_conf = pd.DataFrame(rules, columns=["conseq","antecedent","support_abs","support_perc","confidence","lift"])
    df_rules_conf = df_rules_conf.sort_values(by='lift', ascending=False)
    print("<<<<<<<<< Check del valore "+ valcheck[0] + " >>>>>>>>>>")
    cnt = 0
    for i in df_rules_conf.values:
        if valcheck[0] in i[0]:
            if i[5] > 1:
                print("****** Regola:")
                print(str(i[1]) + " => "+str(i[0]))
                print("**** Support: " + str(i[3]) + " Confidence: "+ str(i[4]) + " Lift: " + str(i[5]))
                print("______________________________")
                cnt = cnt + 1
    print("______________________________")
    print("______________________________")    
    print("SS: " + str(cnt))
    print("______________________________")
    print("______________________________")
    print("<<<<<<<<< Check del valore Not/Attrition + MissingVal >>>>>>>>>>")
    for i in df_rules_conf.values:
        if valcheck[1] in i[1]:
            #if "Attrition" in i[0]:
            if i[5] > 1:
                print("****** Regola:")
                print(str(i[1]) + " => "+str(i[0]))
                print("**** Support: " + str(i[3]) + " Confidence: "+ str(i[4]) + " Lift: " + str(i[5]))
                print("______________________________")
    return df_rules_conf

# %%
for i in missing_attr:
    print(df_new[i].unique())
# Out:
# ['Male/Gender' 'Missing/Gender' 'Female/Gender']
# ['Travel_Rarely/BusinessTravel' 'Travel_Frequently/BusinessTravel'
#  'Missing/BusinessTravel' 'Non-Travel/BusinessTravel']
# ['3.0/PerformanceRating' 'Missing/PerformanceRating'
#  '4.0/PerformanceRating']

# %%
baskets = df_new.values.tolist()

# %%
for i in df_new["Gender"].unique():
    if i != "Missing/Gender":
        x = extractRules(baskets, 2, 2, 60, [i, "Missing/Gender"])
# Out:
# <<<<<<<<< Check del valore Male/Gender >>>>>>>>>>
# ****** Regola:
# ('Missing/PerformanceRating', '<=6/TotalWorkingYears_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 85.0 Lift: 1.485731272294887
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/JobLevel', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 83.33333333333334 Lift: 1.4565992865636148
# ______________________________
# ****** Regola:
# ('2/JobLevel', '3/Education', '1/StockOptionLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 83.33333333333334 Lift: 1.4565992865636148
# ______________________________
# ****** Regola:
# ('2/Education', '<=6/TotalWorkingYears_Range', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 83.33333333333334 Lift: 1.4565992865636148
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 82.5 Lift: 1.4420332936979785
# ______________________________
# ****** Regola:
# ('1.0/YearsAtCompany', '1/NumCompaniesWorked', 'Research & Development/Department') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 82.5 Lift: 1.4420332936979785
# ______________________________
# ****** Regola:
# ('2/JobInvolvement', '<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', 'Low/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.517006802721088 Confidence: 82.22222222222221 Lift: 1.4371779627427665
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', 'Low/MonthlyIncome_Range', '1/StockOptionLevel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 81.57894736842105 Lift: 1.4259340384254333
# ______________________________
# ****** Regola:
# ('Divorced/MaritalStatus', '2/JobLevel', '1/StockOptionLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 81.57894736842105 Lift: 1.4259340384254333
# ______________________________
# ****** Regola:
# ('10.0/YearsAtCompany', '0/StockOptionLevel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 81.25 Lift: 1.4201843043995244
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '4/Education', 'Medium/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 81.08108108108108 Lift: 1.4172317382781117
# ______________________________
# ****** Regola:
# ('2/JobLevel', '3/Education', '1/StockOptionLevel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 81.08108108108108 Lift: 1.4172317382781117
# ______________________________
# ****** Regola:
# ('2/Education', '<=6/TotalWorkingYears_Range', 'Very Low/MonthlyIncome_Range') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 81.08108108108108 Lift: 1.4172317382781117
# ______________________________
# ****** Regola:
# ('2/Education', 'Medium/TotalSatisfaction_Range', 'Very Low/MonthlyIncome_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 80.95238095238095 Lift: 1.4149821640903686
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/JobLevel', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 80.95238095238095 Lift: 1.4149821640903686
# ______________________________
# ****** Regola:
# ('2/Education', '<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 80.48780487804879 Lift: 1.4068617499492475
# ______________________________
# ****** Regola:
# ('1.0/YearsAtCompany', '1/NumCompaniesWorked', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 80.0 Lift: 1.3983353151010702
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Sales/Department', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 80.0 Lift: 1.3983353151010702
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/JobLevel', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 80.0 Lift: 1.3983353151010702
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '4/Education', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 79.54545454545455 Lift: 1.3903902280834504
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', 'Very Low/MonthlyIncome_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('2/JobInvolvement', '<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', '1/JobLevel', 'Low/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('3/JobLevel', 'Married/MaritalStatus', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('3/JobLevel', 'Life Sciences/EducationField', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('Divorced/MaritalStatus', '2/JobLevel', '1/StockOptionLevel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Very Low/MonthlyIncome_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '<=12/PercentSalaryHike_Range', '2/JobLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 79.48717948717949 Lift: 1.3893716271837555
# ______________________________
# ****** Regola:
# ('2/NumCompaniesWorked', '3/JobInvolvement', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 79.24528301886792 Lift: 1.385143472505777
# ______________________________
# ****** Regola:
# ('>2 <=7/DistanceFromHome_Range', '2.0/TrainingTimesLastYear', '1/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.585034013605442 Confidence: 79.16666666666666 Lift: 1.383769322235434
# ______________________________
# ****** Regola:
# ('>2 <=7/DistanceFromHome_Range', '2.0/TrainingTimesLastYear', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.585034013605442 Confidence: 79.16666666666666 Lift: 1.383769322235434
# ______________________________
# ****** Regola:
# ('10.0/YearsAtCompany', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 79.06976744186046 Lift: 1.3820756021347786
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '>2 <=7/DistanceFromHome_Range', '3/JobInvolvement') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 79.06976744186046 Lift: 1.3820756021347786
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '>2 <=7/DistanceFromHome_Range', 'Sales/Department', '3/JobInvolvement') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 79.06976744186046 Lift: 1.3820756021347786
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '1/StockOptionLevel', '3/JobInvolvement', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('Missing/PerformanceRating', '2/JobLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Sales/Department', '3/Education', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', '2/JobLevel', '1/StockOptionLevel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3.0/TrainingTimesLastYear', '3/JobInvolvement', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', '2/JobLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/JobLevel', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 78.94736842105263 Lift: 1.3799361662181613
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '2/JobLevel', '1/StockOptionLevel') => Male/Gender
# **** Support: 2.7891156462585034 Confidence: 78.84615384615384 Lift: 1.3781670172871123
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Very Low/MonthlyIncome_Range', 'Married/MaritalStatus', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.517006802721088 Confidence: 78.72340425531915 Lift: 1.376021453689883
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 78.57142857142857 Lift: 1.3733650416171226
# ______________________________
# ****** Regola:
# ('10.0/YearsAtCompany', '0/StockOptionLevel', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 78.57142857142857 Lift: 1.3733650416171226
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '<=12/PercentSalaryHike_Range', '2/JobLevel') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 78.57142857142857 Lift: 1.3733650416171226
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Sales/Department', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 78.57142857142857 Lift: 1.3733650416171226
# ______________________________
# ****** Regola:
# ('3/JobLevel', 'Life Sciences/EducationField', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 78.43137254901961 Lift: 1.3709169755892845
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3.0/TrainingTimesLastYear', '3/JobInvolvement') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 78.43137254901961 Lift: 1.3709169755892845
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Medium/TotalSatisfaction_Range', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 3.197278911564626 Confidence: 78.33333333333333 Lift: 1.3692033293697978
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 78.26086956521739 Lift: 1.3679367212945253
# ______________________________
# ****** Regola:
# ('>6 <=10/TotalWorkingYears_Range', 'Medium/TotalSatisfaction_Range', '2/JobLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 78.26086956521739 Lift: 1.3679367212945253
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', 'Life Sciences/EducationField', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 78.26086956521739 Lift: 1.3679367212945253
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 78.04878048780488 Lift: 1.3642295757083611
# ______________________________
# ****** Regola:
# ('Non-Travel/BusinessTravel', '3/Education') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 78.04878048780488 Lift: 1.3642295757083611
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 78.04878048780488 Lift: 1.3642295757083611
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', '3/JobInvolvement') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 78.04878048780488 Lift: 1.3642295757083611
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 78.04878048780488 Lift: 1.3642295757083611
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '2/JobLevel', '1/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 78.0 Lift: 1.3633769322235434
# ______________________________
# ****** Regola:
# ('3/NumCompaniesWorked', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 77.77777777777779 Lift: 1.3594926674593737
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', '2/JobLevel', '1/StockOptionLevel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 77.77777777777779 Lift: 1.3594926674593737
# ______________________________
# ****** Regola:
# ('>6 <=10/TotalWorkingYears_Range', '2/JobLevel', '1/StockOptionLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 77.77777777777779 Lift: 1.3594926674593737
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '3/Education', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 77.77777777777779 Lift: 1.3594926674593737
# ______________________________
# ****** Regola:
# ('3/Education', 'Low/MonthlyIncome_Range', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 77.77777777777779 Lift: 1.3594926674593737
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel', '3/JobInvolvement') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 77.77777777777779 Lift: 1.3594926674593737
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.585034013605442 Confidence: 77.55102040816327 Lift: 1.3555291319857312
# ______________________________
# ****** Regola:
# ('2/Education', '<=12/PercentSalaryHike_Range', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.585034013605442 Confidence: 77.55102040816327 Lift: 1.3555291319857312
# ______________________________
# ****** Regola:
# ('2/Education', '1/NumCompaniesWorked', 'Low/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('Marketing/EducationField', 'Sales Executive/JobRole', '<=12/PercentSalaryHike_Range') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('3/NumCompaniesWorked', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', 'Very Low/MonthlyIncome_Range', '3/JobInvolvement', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '1/StockOptionLevel', '3.0/TrainingTimesLastYear', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('2/Education', '<=6/TotalWorkingYears_Range', '1/JobLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('1/NumCompaniesWorked', 'Medium/TotalSatisfaction_Range', 'Married/MaritalStatus', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('Marketing/EducationField', 'Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Low/MonthlyIncome_Range', '0/StockOptionLevel', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('Missing/PerformanceRating', '0/StockOptionLevel', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 77.5 Lift: 1.3546373365041617
# ______________________________
# ****** Regola:
# ('2/Education', '<=6/TotalWorkingYears_Range', '3/JobInvolvement') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('3/Education', '1/StockOptionLevel', 'Low/TotalSatisfaction_Range', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', '2/JobLevel', '1/StockOptionLevel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Single/MaritalStatus', 'Low/MonthlyIncome_Range', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '<=12/PercentSalaryHike_Range', '3.0/TrainingTimesLastYear') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Single/MaritalStatus', 'Low/MonthlyIncome_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '1/StockOptionLevel', '3/JobInvolvement', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Sales/Department', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('2/JobInvolvement', '<=6/TotalWorkingYears_Range', '1/JobLevel', 'Low/TotalSatisfaction_Range', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 77.27272727272727 Lift: 1.350664792995352
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 77.14285714285715 Lift: 1.3483947681331747
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', '2/JobLevel') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 77.14285714285715 Lift: 1.3483947681331747
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 77.14285714285715 Lift: 1.3483947681331747
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Life Sciences/EducationField', 'Very Low/MonthlyIncome_Range', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.517006802721088 Confidence: 77.08333333333334 Lift: 1.3473543400713437
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Married/MaritalStatus', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '<=2/DistanceFromHome_Range', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('3/JobLevel', 'Low/TotalSatisfaction_Range', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Medium/TotalSatisfaction_Range', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('Missing/PerformanceRating', '2/JobLevel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('Missing/PerformanceRating', '2/JobLevel', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('Non-Travel/BusinessTravel', '1/StockOptionLevel', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', 'Low/MonthlyIncome_Range', 'Life Sciences/EducationField', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 3.4013605442176873 Confidence: 76.92307692307693 Lift: 1.3445531875971828
# ______________________________
# ****** Regola:
# ('3/Education', 'Low/MonthlyIncome_Range', '1/StockOptionLevel', 'Low/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 76.74418604651163 Lift: 1.34142631971905
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', 'Low/MonthlyIncome_Range', '1/StockOptionLevel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 76.74418604651163 Lift: 1.34142631971905
# ______________________________
# ****** Regola:
# ('>18/PercentSalaryHike_Range', '<=6/TotalWorkingYears_Range', '1/JobLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 76.74418604651163 Lift: 1.34142631971905
# ______________________________
# ****** Regola:
# ('Technical Degree/EducationField', 'Low/TotalSatisfaction_Range', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 76.74418604651163 Lift: 1.34142631971905
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '4/Education', 'Life Sciences/EducationField') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 76.74418604651163 Lift: 1.34142631971905
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/JobLevel', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', 'Research & Development/Department') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 76.74418604651163 Lift: 1.34142631971905
# ______________________________
# ****** Regola:
# ('3/Education', '1/StockOptionLevel', 'Low/TotalSatisfaction_Range', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', '<=6/TotalWorkingYears_Range', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Life Sciences/EducationField', 'Married/MaritalStatus', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', '2/JobLevel', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('>6 <=10/TotalWorkingYears_Range', 'Medium/TotalSatisfaction_Range', '2/JobLevel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 76.59574468085107 Lift: 1.3388316846712374
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 76.47058823529412 Lift: 1.3366440511995523
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 76.47058823529412 Lift: 1.3366440511995523
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '3/Education', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 76.47058823529412 Lift: 1.3366440511995523
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 76.47058823529412 Lift: 1.3366440511995523
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3.0/TrainingTimesLastYear', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 76.36363636363637 Lift: 1.3347746189601124
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 76.36363636363637 Lift: 1.3347746189601124
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 76.27118644067797 Lift: 1.3331586690582236
# ______________________________
# ****** Regola:
# ('10.0/YearsAtCompany', '0/StockOptionLevel') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 76.27118644067797 Lift: 1.3331586690582236
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/NumCompaniesWorked', '1/JobLevel', 'Very Low/MonthlyIncome_Range', '3/JobInvolvement') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 76.19047619047619 Lift: 1.3317479191438764
# ______________________________
# ****** Regola:
# ('>15/TotalWorkingYears_Range', '>2 <=7/DistanceFromHome_Range', '1/StockOptionLevel') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 76.19047619047619 Lift: 1.3317479191438764
# ______________________________
# ****** Regola:
# ('2/Education', '<=6/TotalWorkingYears_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.2653061224489797 Confidence: 76.19047619047619 Lift: 1.3317479191438764
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Very Low/MonthlyIncome_Range', 'Low/TotalSatisfaction_Range', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.1768707482993195 Confidence: 76.19047619047619 Lift: 1.3317479191438764
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '4/Education', '2/JobLevel') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 76.08695652173914 Lift: 1.329938479036344
# ______________________________
# ****** Regola:
# ('2/Education', 'Medium/TotalSatisfaction_Range', 'Very Low/MonthlyIncome_Range') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 76.08695652173914 Lift: 1.329938479036344
# ______________________________
# ****** Regola:
# ('1/StockOptionLevel', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 76.08695652173914 Lift: 1.329938479036344
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '3/Education', 'Low/TotalSatisfaction_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.380952380952381 Confidence: 76.08695652173914 Lift: 1.329938479036344
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '1/NumCompaniesWorked', 'Married/MaritalStatus') => Male/Gender
# **** Support: 2.7891156462585034 Confidence: 75.92592592592592 Lift: 1.3271237944246268
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Single/MaritalStatus', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7891156462585034 Confidence: 75.92592592592592 Lift: 1.3271237944246268
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Single/MaritalStatus', '0/StockOptionLevel', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7891156462585034 Confidence: 75.92592592592592 Lift: 1.3271237944246268
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Sales/Department', 'Single/MaritalStatus', '0/StockOptionLevel', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7891156462585034 Confidence: 75.92592592592592 Lift: 1.3271237944246268
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Sales/Department', 'Single/MaritalStatus', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7891156462585034 Confidence: 75.92592592592592 Lift: 1.3271237944246268
# ______________________________
# ****** Regola:
# ('1.0/YearsAtCompany', '1/NumCompaniesWorked') => Male/Gender
# **** Support: 3.197278911564626 Confidence: 75.80645161290323 Lift: 1.3250354800352881
# ______________________________
# ****** Regola:
# ('2/Education', 'Very Low/MonthlyIncome_Range', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.197278911564626 Confidence: 75.80645161290323 Lift: 1.3250354800352881
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', '2/JobLevel', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Sales/Department', '3/Education', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('3/NumCompaniesWorked', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Life Sciences/EducationField', '0/StockOptionLevel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', 'Medical/EducationField', '>6 <=10/TotalWorkingYears_Range') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', 'Low/MonthlyIncome_Range', 'Life Sciences/EducationField', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('2/NumCompaniesWorked', '3/JobInvolvement', 'Research & Development/Department', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('2/JobInvolvement', 'Sales/Department', '1/NumCompaniesWorked') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('Missing/PerformanceRating', '2/JobLevel', 'Married/MaritalStatus') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Sales/Department', '2/JobLevel', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', '0/StockOptionLevel', '3.0/TrainingTimesLastYear', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.1088435374149657 Confidence: 75.60975609756098 Lift: 1.3215974014674747
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Very Low/MonthlyIncome_Range') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 75.55555555555556 Lift: 1.3206500198176774
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '<=12/PercentSalaryHike_Range', 'Sales/Department', 'Very Low/MonthlyIncome_Range') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 75.55555555555556 Lift: 1.3206500198176774
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '1/StockOptionLevel', '3.0/TrainingTimesLastYear', 'Research & Development/Department', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 75.55555555555556 Lift: 1.3206500198176774
# ______________________________
# ****** Regola:
# ('3/JobLevel', 'Married/MaritalStatus', 'Research & Development/Department', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.312925170068027 Confidence: 75.55555555555556 Lift: 1.3206500198176774
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/JobLevel', '1/StockOptionLevel', 'Low/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.517006802721088 Confidence: 75.51020408163265 Lift: 1.319857312722949
# ______________________________
# ****** Regola:
# ('2/JobLevel', 'Low/MonthlyIncome_Range', '1/StockOptionLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.517006802721088 Confidence: 75.51020408163265 Lift: 1.319857312722949
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', 'Research & Development/Department') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 75.47169811320755 Lift: 1.3191842595293115
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', 'Sales/Department', '3/Education') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 75.47169811320755 Lift: 1.3191842595293115
# ______________________________
# ****** Regola:
# ('<=6/TotalWorkingYears_Range', '1/StockOptionLevel', 'Low/TotalSatisfaction_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.7210884353741496 Confidence: 75.47169811320755 Lift: 1.3191842595293115
# ______________________________
# ****** Regola:
# ('2/Education', '<=12/PercentSalaryHike_Range', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.925170068027211 Confidence: 75.43859649122807 Lift: 1.3186056699417985
# ______________________________
# ****** Regola:
# ('2/NumCompaniesWorked', '3/JobInvolvement', '3.0/PerformanceRating') => Male/Gender
# **** Support: 3.1292517006802725 Confidence: 75.40983606557377 Lift: 1.3181029609559267
# ______________________________
# ****** Regola:
# ('1/JobLevel', 'Low/MonthlyIncome_Range', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '1/NumCompaniesWorked', 'Medium/TotalSatisfaction_Range') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('2.0/TrainingTimesLastYear', 'Low/MonthlyIncome_Range', '1/StockOptionLevel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('Non-Travel/BusinessTravel', '1/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', 'Low/MonthlyIncome_Range', '1/StockOptionLevel', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('10.0/YearsAtCompany', 'Single/MaritalStatus') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('10.0/YearsAtCompany', 'Single/MaritalStatus', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('Missing/BusinessTravel', 'Sales/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>7 <=14/DistanceFromHome_Range', '2/JobLevel', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('2/Education', 'Very Low/MonthlyIncome_Range', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('<=12/PercentSalaryHike_Range', 'Medium/TotalSatisfaction_Range', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Single/MaritalStatus', 'Low/MonthlyIncome_Range') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', '1/StockOptionLevel', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Sales/Department', 'Single/MaritalStatus', 'Low/MonthlyIncome_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>15/TotalWorkingYears_Range', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>15/TotalWorkingYears_Range', 'Medium/TotalSatisfaction_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', 'Life Sciences/EducationField', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', 'Life Sciences/EducationField', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', 'Life Sciences/EducationField', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('Manufacturing Director/JobRole', '1/StockOptionLevel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '2.0/TrainingTimesLastYear', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.3109393579072532
# ______________________________
# ...
# ______________________________
# ****** Regola:
# ('2/JobLevel', '3/Education', 'Life Sciences/EducationField', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('2/JobLevel', '1/StockOptionLevel', '3/JobInvolvement', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', 'Life Sciences/EducationField', 'Research & Development/Department') => Male/Gender
# **** Support: 4.285714285714286 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Sales/Department', '3/Education', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('3/JobLevel', 'Medium/TotalSatisfaction_Range', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '4/Education', 'Sales/Department', '2/JobLevel') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', 'Very Low/MonthlyIncome_Range', 'Research & Development/Department') => Male/Gender
# **** Support: 4.6938775510204085 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', 'Sales/Department', '2/JobLevel', '3/Education', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14 <=18/PercentSalaryHike_Range', '>15/TotalWorkingYears_Range', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Single/MaritalStatus', 'Very Low/MonthlyIncome_Range', '3.0/TrainingTimesLastYear', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>6 <=10/TotalWorkingYears_Range', '1/NumCompaniesWorked', 'Married/MaritalStatus', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14 <=18/PercentSalaryHike_Range', 'Very Low/MonthlyIncome_Range', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 3.4693877551020407 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('<=2/DistanceFromHome_Range', '2.0/TrainingTimesLastYear', 'Married/MaritalStatus') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Medical/EducationField', '3/Education', 'Low/TotalSatisfaction_Range', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('0/StockOptionLevel', '3.0/TrainingTimesLastYear', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 9.591836734693878 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Very Low/MonthlyIncome_Range', 'Low/TotalSatisfaction_Range', '3.0/TrainingTimesLastYear', '3.0/PerformanceRating') => Male/Gender
# **** Support: 3.4693877551020407 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('2/JobLevel', 'Life Sciences/EducationField', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('2/Education', '>14/DistanceFromHome_Range', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Medical/EducationField', '3/Education', '0/StockOptionLevel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', '3/Education', 'Travel_Rarely/BusinessTravel', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('0/StockOptionLevel', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Research & Development/Department', '3.0/PerformanceRating') => Male/Gender
# **** Support: 3.2653061224489797 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Single/MaritalStatus', 'Very Low/MonthlyIncome_Range', '0/StockOptionLevel', '3.0/TrainingTimesLastYear', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('2/JobLevel', 'Very Low/MonthlyIncome_Range', 'Married/MaritalStatus', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.857142857142857 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Medical/EducationField', 'Low/MonthlyIncome_Range', '3.0/TrainingTimesLastYear', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>6 <=10/TotalWorkingYears_Range', '1/NumCompaniesWorked', 'Life Sciences/EducationField', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Single/MaritalStatus', 'Life Sciences/EducationField', '3.0/TrainingTimesLastYear', 'Research & Development/Department') => Male/Gender
# **** Support: 2.6530612244897958 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('3/JobLevel', '3/Education', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '1/JobLevel', 'Married/MaritalStatus', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14 <=18/PercentSalaryHike_Range', '3/Education', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '2/JobLevel', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14 <=18/PercentSalaryHike_Range', '2.0/TrainingTimesLastYear', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Very Low/MonthlyIncome_Range', '0/StockOptionLevel', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14 <=18/PercentSalaryHike_Range', '<=6/TotalWorkingYears_Range', '0/StockOptionLevel') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('4.0/PerformanceRating', 'Low/MonthlyIncome_Range', 'Travel_Rarely/BusinessTravel') => Male/Gender
# **** Support: 2.4489795918367347 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14/DistanceFromHome_Range', '>15/TotalWorkingYears_Range') => Male/Gender
# **** Support: 3.6734693877551026 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Very Low/MonthlyIncome_Range', 'Low/TotalSatisfaction_Range', '3.0/PerformanceRating') => Male/Gender
# **** Support: 7.346938775510205 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>6 <=10/TotalWorkingYears_Range', 'Medium/TotalSatisfaction_Range', '3.0/PerformanceRating') => Male/Gender
# **** Support: 4.8979591836734695 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>12 <=14/PercentSalaryHike_Range', '2/JobLevel', 'Travel_Rarely/BusinessTravel', 'Research & Development/Department') => Male/Gender
# **** Support: 2.0408163265306123 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('>14 <=18/PercentSalaryHike_Range', '2/JobLevel', 'Research & Development/Department', '3.0/PerformanceRating') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Laboratory Technician/JobRole', '1/StockOptionLevel', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('2/JobLevel', 'Life Sciences/EducationField', '3.0/TrainingTimesLastYear', '3/JobInvolvement', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Laboratory Technician/JobRole', '1/StockOptionLevel', '3/JobInvolvement', 'Research & Development/Department', 'Not_Attrition/Attrition') => Male/Gender
# **** Support: 2.2448979591836733 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ****** Regola:
# ('Sales Executive/JobRole', '4/Education', '2/JobLevel') => Male/Gender
# **** Support: 3.061224489795918 Confidence: 60.0 Lift: 1.0487514863258025
# ______________________________
# ______________________________
# ______________________________
# SS: 8621
# ______________________________
# ______________________________
# <<<<<<<<< Check del valore Not/Attrition + MissingVal >>>>>>>>>>
# ****** Regola:
# ('Missing/Gender', '3/JobInvolvement') => Research & Development/Department
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.147242455775234
# ______________________________
# ****** Regola:
# ('Missing/Gender', '3.0/PerformanceRating') => Research & Development/Department
# **** Support: 2.517006802721088 Confidence: 74.0 Lift: 1.131945889698231
# ______________________________
# ****** Regola:
# ('Missing/Gender',) => Research & Development/Department
# **** Support: 3.6054421768707483 Confidence: 70.66666666666667 Lift: 1.0809573361082205
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Not_Attrition/Attrition') => Research & Development/Department
# **** Support: 2.925170068027211 Confidence: 70.49180327868852 Lift: 1.0782825267395644
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Travel_Rarely/BusinessTravel') => Research & Development/Department
# **** Support: 2.0408163265306123 Confidence: 69.76744186046511 Lift: 1.0672022844420783
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Research & Development/Department') => 3/JobInvolvement
# **** Support: 2.2448979591836733 Confidence: 62.264150943396224 Lift: 1.0544735240413876
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Not_Attrition/Attrition') => 3/JobInvolvement
# **** Support: 2.517006802721088 Confidence: 60.65573770491803 Lift: 1.0272342675832893
# ______________________________
# ****** Regola:
# ('Missing/Gender', '3/Education') => Not_Attrition/Attrition
# **** Support: 2.1768707482993195 Confidence: 84.21052631578947 Lift: 1.0039697784607504
# ______________________________
# ****** Regola:
# ('Missing/Gender', '3/JobInvolvement') => Not_Attrition/Attrition
# **** Support: 2.517006802721088 Confidence: 84.0909090909091 Lift: 1.0025436850254368
# ______________________________
# <<<<<<<<< Check del valore Female/Gender >>>>>>>>>>
# ****** Regola:
# ('Laboratory Technician/JobRole', '1/JobLevel', 'Low/MonthlyIncome_Range', '3/JobInvolvement') => Female/Gender
# **** Support: 2.1088435374149657 Confidence: 63.26530612244898 Lift: 1.6787003610108304
# ______________________________
# ****** Regola:
# ('Laboratory Technician/JobRole', '1/JobLevel', 'Low/MonthlyIncome_Range', '3/JobInvolvement', 'Research & Development/Department') => Female/Gender
# **** Support: 2.1088435374149657 Confidence: 63.26530612244898 Lift: 1.6787003610108304
# ______________________________
# ****** Regola:
# ('1/Education', 'Low/MonthlyIncome_Range', '3.0/PerformanceRating') => Female/Gender
# **** Support: 2.312925170068027 Confidence: 62.96296296296296 Lift: 1.6706778981147212
# ______________________________
# ****** Regola:
# ('>18/PercentSalaryHike_Range', '1/StockOptionLevel', '3/JobInvolvement', 'Travel_Rarely/BusinessTravel', 'Not_Attrition/Attrition') => Female/Gender
# **** Support: 2.0408163265306123 Confidence: 62.5 Lift: 1.6583935018050542
# ______________________________
# ****** Regola:
# ('Sales/Department', 'Low/TotalSatisfaction_Range', 'Married/MaritalStatus', '3.0/PerformanceRating', 'Not_Attrition/Attrition') => Female/Gender
# **** Support: 2.0408163265306123 Confidence: 61.224489795918366 Lift: 1.6245487364620939
# ______________________________
# ______________________________
# ______________________________
# SS: 5
# ______________________________
# ______________________________
# <<<<<<<<< Check del valore Not/Attrition + MissingVal >>>>>>>>>>
# ****** Regola:
# ('Missing/Gender', '3/JobInvolvement') => Research & Development/Department
# **** Support: 2.2448979591836733 Confidence: 75.0 Lift: 1.147242455775234
# ______________________________
# ****** Regola:
# ('Missing/Gender', '3.0/PerformanceRating') => Research & Development/Department
# **** Support: 2.517006802721088 Confidence: 74.0 Lift: 1.131945889698231
# ______________________________
# ****** Regola:
# ('Missing/Gender',) => Research & Development/Department
# **** Support: 3.6054421768707483 Confidence: 70.66666666666667 Lift: 1.0809573361082205
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Not_Attrition/Attrition') => Research & Development/Department
# **** Support: 2.925170068027211 Confidence: 70.49180327868852 Lift: 1.0782825267395644
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Travel_Rarely/BusinessTravel') => Research & Development/Department
# **** Support: 2.0408163265306123 Confidence: 69.76744186046511 Lift: 1.0672022844420783
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Research & Development/Department') => 3/JobInvolvement
# **** Support: 2.2448979591836733 Confidence: 62.264150943396224 Lift: 1.0544735240413876
# ______________________________
# ****** Regola:
# ('Missing/Gender', 'Not_Attrition/Attrition') => 3/JobInvolvement
# **** Support: 2.517006802721088 Confidence: 60.65573770491803 Lift: 1.0272342675832893
# ______________________________
# ****** Regola:
# ('Missing/Gender', '3/Education') => Not_Attrition/Attrition
# **** Support: 2.1768707482993195 Confidence: 84.21052631578947 Lift: 1.0039697784607504
# ______________________________
# ****** Regola:
# ('Missing/Gender', '3/JobInvolvement') => Not_Attrition/Attrition
# **** Support: 2.517006802721088 Confidence: 84.0909090909091 Lift: 1.0025436850254368
# ______________________________

# %%
def predict_FromRules(df, baskets, minz, support, confidence, valcheck):
    rules = apriori(baskets, supp=support, zmin=minz, target='r', conf=confidence, report='aSCl', mode='o')
    pred = ["NotPredicted" for i in range(0, len(df))]
    df_rules_conf = pd.DataFrame(rules, columns=["conseq","antecedent","support_abs","support_perc","confidence","lift"])
    df_rules_conf = df_rules_conf.sort_values(by='lift', ascending=False)
    dt = {}
    for i in df[valcheck].unique():
        if "Missing" not in i:
            dt[i] = df_rules_conf[df_rules_conf["conseq"] == i][:100]
    for i in df[valcheck].unique():
        if "Missing" not in i:
            antecedente = dt[i]["antecedent"]
            for k in antecedente:
                associazioni = {}
                for j in range(0, len(k)):
                    valore, attributo = k[j].split("/")
                    associazioni[attributo] = valore
                x = df.copy()
                for s in associazioni:
                    x = x[x[s]==(str(associazioni[s]) + "/"+s)]
                indici = list(x.index)
                for c in indici:
                    #if(pred[c] == "NotPredicted"):
                    pred[c] = i
    return pred, dt

# %%
baskets = df_new.values.tolist()

# %% [markdown]
# ### Sostituzione MV per Gender

# %%
pred, dt = predict_FromRules(df_new, baskets, 2, 2, 60, "Gender")

# %%
original_df["GenderPredicted"] = pred

# %%
dict(Counter(pred))["NotPredicted"]/len(pred) * 100
# Out:
# 25.37414965986395

# %%
y_true = original_df[original_df["GenderPredicted"]!="NotPredicted"]["Gender"]
y_pred = original_df[original_df["GenderPredicted"]!="NotPredicted"]["GenderPredicted"]

# %%
result_pred(y_true, y_pred)
# Out:
# ***** Calcolo dell'accuracy *****
# Frazione di campioni correttamente correlati: 0.7247
# Numero di campioni correttamente correlati:  795
# ____________________________________________

# %% [markdown]
# ### Sostituzione MV per PerformanceRating

# %%
pred, dt = predict_FromRules(df_new, baskets, 2, 2, 60, "PerformanceRating")

# %%
original_df["PerformanceRatingPredicted"] = pred

# %%
dict(Counter(pred))["NotPredicted"]/len(pred) * 100
# Out:
# 43.06122448979592

# %%
y_true = original_df[original_df["PerformanceRatingPredicted"]!="NotPredicted"]["PerformanceRating"]
y_pred = original_df[original_df["PerformanceRatingPredicted"]!="NotPredicted"]["PerformanceRatingPredicted"]

# %%
result_pred(y_true, y_pred)
# Out:
# ***** Calcolo dell'accuracy *****
# Frazione di campioni correttamente correlati: 0.9415
# Numero di campioni correttamente correlati:  788
# ____________________________________________

# %% [markdown]
# ### Sostituzione MV per BusinessTravel

# %%
pred, dt = predict_FromRules(df_new, baskets, 2, 2, 60, "BusinessTravel")

# %%
original_df["BusinessTravelPredicted"] = pred

# %%
dict(Counter(pred))["NotPredicted"]/len(pred) * 100
# Out:
# 36.12244897959184

# %%
y_true = original_df[original_df["BusinessTravelPredicted"]!="NotPredicted"]["BusinessTravel"]
y_pred = original_df[original_df["BusinessTravelPredicted"]!="NotPredicted"]["BusinessTravelPredicted"]

# %%
result_pred(y_true, y_pred)
# Out:
# ***** Calcolo dell'accuracy *****
# Frazione di campioni correttamente correlati: 0.8158
# Numero di campioni correttamente correlati:  766
# ____________________________________________
